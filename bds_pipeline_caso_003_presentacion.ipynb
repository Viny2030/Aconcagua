# %% [markdown]
# <p align="center">
# <img src="https://pypi.org/static/images/logo-small.8998e9d1.svg">
# </p>

# %% [markdown]
# <p align="justify">
# 👀 El objetivo es predecir si el cliente va a solicitar tarjeta...

# %% [markdown]
#  # **<font color="DarkBlue">Registros Bancarios</font>**

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/cristiandarioortegayubro/BDS/main/datasets/RegistrosBanco.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2000 non-null   int64
#  1   Nombre               2000 non-null   object
#  2   Apellido             2000 non-null   object
#  3   email                2000 non-null   object
#  4   Genero               2000 non-null   object
#  5   ip_address           2000 non-null   object
#  6   Edad                 2000 non-null   int64
#  7   Experiencia          2000 non-null   int64
#  8   Ingresos             2000 non-null   int64
#  9   Familiares           2000 non-null   int64
#  10  Promedio Gastos      2000 non-null   float64
#  11  Educacion            2000 non-null   object
#  12  Hipotecas            2000 non-null   int64
#  13  Prestamos            2000 non-null   bool
#  14  Activos Financieros  2000 non-null   bool
#  15  Online               2000 non-null   bool
#  16  Tarjeta              2000 non-null   bool
#  17  Codigo Pais          2000 non-null   object
#  18  Pais                 2000 non-null   object
#  19  Latitud              2000 non-null   object
#  20  Longitud             2000 non-null   object
# dtypes: bool(4), float64(1), int64(6), object(10)
# memory usage: 273.6+ KB

# %%
data.head()
# Out:
#    id    Nombre    Apellido                          email    Genero  \
# 0   1  Harmonia     Shearme        hshearme0@artisteer.com    Female
# 1   2    Krisha     Clampin               kclampin1@hp.com      Male
# 2   3   Gunther     Kiezler            gkiezler2@yahoo.com      Male
# 3   4    Wallie        Dwyr             wdwyr3@tinypic.com  Bigender
# 4   5    Farley  Simoncello  fsimoncello4@sciencedaily.com      Male
#
#        ip_address  Edad  Experiencia  Ingresos  Familiares  ...    Educacion  \
# 0    30.7.111.246    34           11    913696           3  ...  No graduado
# 1   205.80.60.102    38            1    591752           4  ...  No graduado
# 2  237.140.247.16    36           18    723888           4  ...     Graduado
# 3   224.155.50.31    37           26    870003           2  ...     Graduado
# 4  62.141.223.205    36           21    576566           3  ...  No graduado
#
#   Hipotecas  Prestamos  Activos Financieros  Online  Tarjeta  Codigo Pais  \
# 0       123      False                 True    True    False           BR
# 1        77      False                 True   False    False           BR
# 2        18      False                 True   False     True           BR
# 3        96      False                 True    True    False           BR
# 4        39       True                 True   False     True           BR
#
#      Pais       Latitud      Longitud
# 0  Brazil  -257.464.549  -530.615.734
# 1  Brazil  -293.652.193  -519.580.164
# 2  Brazil  -175.582.645  -495.687.416
# 3  Brazil  -207.430.332  -466.096.926
# 4  Brazil   -82.197.304  -377.237.678
#
# [5 rows x 21 columns]

# %%
data.drop(columns=["id", "Nombre", "Apellido", "email", "Pais"], inplace=True)

# %%
data.head()
# Out:
#      Genero      ip_address  Edad  Experiencia  Ingresos  Familiares  \
# 0    Female    30.7.111.246    34           11    913696           3
# 1      Male   205.80.60.102    38            1    591752           4
# 2      Male  237.140.247.16    36           18    723888           4
# 3  Bigender   224.155.50.31    37           26    870003           2
# 4      Male  62.141.223.205    36           21    576566           3
#
#    Promedio Gastos    Educacion  Hipotecas  Prestamos  Activos Financieros  \
# 0             2.26  No graduado        123      False                 True
# 1             2.22  No graduado         77      False                 True
# 2             2.17     Graduado         18      False                 True
# 3             0.42     Graduado         96      False                 True
# 4             0.84  No graduado         39       True                 True
#
#    Online  Tarjeta Codigo Pais       Latitud      Longitud
# 0    True    False          BR  -257.464.549  -530.615.734
# 1   False    False          BR  -293.652.193  -519.580.164
# 2   False     True          BR  -175.582.645  -495.687.416
# 3    True    False          BR  -207.430.332  -466.096.926
# 4   False     True          BR   -82.197.304  -377.237.678

# %%
target_name = "Tarjeta"
y = data[target_name]
X = data.drop(columns=[target_name])

# %%
X.head()
# Out:
#      Genero      ip_address  Edad  Experiencia  Ingresos  Familiares  \
# 0    Female    30.7.111.246    34           11    913696           3
# 1      Male   205.80.60.102    38            1    591752           4
# 2      Male  237.140.247.16    36           18    723888           4
# 3  Bigender   224.155.50.31    37           26    870003           2
# 4      Male  62.141.223.205    36           21    576566           3
#
#    Promedio Gastos    Educacion  Hipotecas  Prestamos  Activos Financieros  \
# 0             2.26  No graduado        123      False                 True
# 1             2.22  No graduado         77      False                 True
# 2             2.17     Graduado         18      False                 True
# 3             0.42     Graduado         96      False                 True
# 4             0.84  No graduado         39       True                 True
#
#    Online Codigo Pais       Latitud      Longitud
# 0    True          BR  -257.464.549  -530.615.734
# 1   False          BR  -293.652.193  -519.580.164
# 2   False          BR  -175.582.645  -495.687.416
# 3    True          BR  -207.430.332  -466.096.926
# 4   False          BR   -82.197.304  -377.237.678

# %%
y.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Tarjeta, dtype: bool

# %% [markdown]
#  # **<font color="DarkBlue">Selección basada en tipos de datos</font>**

# %% [markdown]
# <p align="justify">
# 👀 Separaremos variables categóricas y numéricas usando sus tipos de datos para identificarlas, ya que vimos anteriormente que objeto corresponde a las columnas categóricas (cadenas de caracteres). Hacemos uso del <code>make_column_selector</code> para seleccionar las columnas correspondientes.
# </p>

# %%
from sklearn.compose import make_column_selector as selector

# %% [markdown]
# <p align="justify">
# 👀 En el selector de las columnas numericas excluimos los tipos de datos <code>object</code> porque podemos tener numeros enteros o numeros decimales.
# </p>

# %%
numerical_columns_selector = selector(dtype_exclude=object)
categorical_columns_selector = selector(dtype_include=object)

# %%
numerical_columns = numerical_columns_selector(X)
categorical_columns = categorical_columns_selector(X)

# %%
numerical_columns
# Out:
# ['Edad',
#  'Experiencia',
#  'Ingresos',
#  'Familiares',
#  'Promedio Gastos',
#  'Hipotecas',
#  'Prestamos',
#  'Activos Financieros',
#  'Online']

# %%
categorical_columns
# Out:
# ['Genero', 'ip_address', 'Educacion', 'Codigo Pais', 'Latitud', 'Longitud']

# %% [markdown]
#  # **<font color="DarkBlue">Enviar columnas a un procesador específico</font>**

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
categorical_preprocessor = OneHotEncoder(handle_unknown="ignore")
numerical_preprocessor = StandardScaler()

# %% [markdown]
# <p align="justify">
# 👀 Ahora, creamos el transformador y asociamos cada uno de estos preprocesadores con sus respectivas columnas.
# </p>

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html

# %%
from sklearn.compose import ColumnTransformer

# %%
preprocessor = ColumnTransformer([
    ('one-hot-encoder', categorical_preprocessor, categorical_columns),
    ('standard_scaler', numerical_preprocessor, numerical_columns)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('one-hot-encoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['Genero', 'ip_address', 'Educacion',
#                                   'Codigo Pais', 'Latitud', 'Longitud']),
#                                 ('standard_scaler', StandardScaler(),
#                                  ['Edad', 'Experiencia', 'Ingresos',
#                                   'Familiares', 'Promedio Gastos', 'Hipotecas',
#                                   'Prestamos', 'Activos Financieros',
#                                   'Online'])])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

# %%
model = make_pipeline(preprocessor, LogisticRegression())
model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('one-hot-encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Genero', 'ip_address',
#                                                    'Educacion', 'Codigo Pais',
#                                                    'Latitud', 'Longitud']),
#                                                  ('standard_scaler',
#                                                   StandardScaler(),
#                                                   ['Edad', 'Experiencia',
#                                                    'Ingresos', 'Familiares',
#                                                    'Promedio Gastos',
#                                                    'Hipotecas', 'Prestamos',
#                                                    'Activos Financieros',
#                                                    'Online'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
model.named_steps
# Out:
# {'columntransformer': ColumnTransformer(transformers=[('one-hot-encoder',
#                                   OneHotEncoder(handle_unknown='ignore'),
#                                   ['Genero', 'ip_address', 'Educacion',
#                                    'Codigo Pais', 'Latitud', 'Longitud']),
#                                  ('standard_scaler', StandardScaler(),
#                                   ['Edad', 'Experiencia', 'Ingresos',
#                                    'Familiares', 'Promedio Gastos', 'Hipotecas',
#                                    'Prestamos', 'Activos Financieros',
#                                    'Online'])]),
#  'logisticregression': LogisticRegression()}

# %% [markdown]
#  # **<font color="DarkBlue">Train-test, división del conjunto de datos</font>**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
_ = model.fit(X_train, y_train)

# %% [markdown]
#  # **<font color="DarkBlue">Ajuste y prediccion</font>**

# %%
X_test.head()
# Out:
#       Genero       ip_address  Edad  Experiencia  Ingresos  Familiares  \
# 1860    Male   82.225.151.197    32            6    659475           4
# 353     Male     122.10.41.90    28           15    139634           1
# 1333  Female    26.247.88.145    37           21    836088           3
# 905     Male    4.161.255.169    37            8    767844           1
# 1289    Male  222.176.169.255    35            2    221452           1
#
#       Promedio Gastos    Educacion  Hipotecas  Prestamos  Activos Financieros  \
# 1860             1.62     Graduado         77      False                False
# 353              1.47  No graduado          5       True                 True
# 1333             0.55     Graduado         35      False                False
# 905              2.54     Graduado         85      False                False
# 1289             2.10  No graduado         51      False                 True
#
#       Online Codigo Pais       Latitud      Longitud
# 1860    True          BR   -28.471.976  -490.147.244
# 353    False          AR  -345.937.209  -585.035.787
# 1333   False          BR   -72.893.545  -348.403.408
# 905     True          AR  -346.126.135  -585.321.306
# 1289   False          BR  -229.657.374  -420.279.869

# %%
model.predict(X_test)[:10]
# Out:
# array([False,  True, False, False, False, False, False,  True, False,
#        False])

# %%
y_test[:10]
# Out:
# 1860    False
# 353     False
# 1333     True
# 905      True
# 1289    False
# 1273     True
# 938     False
# 1731     True
# 65       True
# 1323    False
# Name: Tarjeta, dtype: bool

# %%
model.score(X_test, y_test).round(4)
# Out:
# 0.484

# %% [markdown]
#  # **<font color="DarkBlue">Evaluación del modelo con Cross-validation</font>**

# %% [markdown]
# <p align="justify">
# 👀 Un modelo predictivo puede ser evaluado con validación cruzada....
# </p>

# %%
from sklearn.model_selection import cross_validate

# %%
cv_results = cross_validate(model, X, y, cv=5)
cv_results
# Out:
# {'fit_time': array([0.09575558, 0.0992372 , 0.09329057, 0.09895587, 0.11207891]),
#  'score_time': array([0.01688576, 0.01528692, 0.01380682, 0.01371789, 0.01339936]),
#  'test_score': array([0.5275, 0.4525, 0.505 , 0.4775, 0.4975])}

# %%
scores = cv_results["test_score"]
print("")
print("The mean cross-validation accuracy is: "
      f"{scores.mean():.3f} ± {scores.std():.3f}")
# Out:
# The mean cross-validation accuracy is: 0.492 ± 0.025

# %% [markdown]
#  # **<font color="DarkBlue">¿Conclusiones?...</font>**

# %% [markdown]
# <p align="justify">
# 👀 En este colab nosotros:<br>
# <br>
# ✅ Cargamos los datos de un archivo <code>CSV</code> usando <code>Pandas</code>.
# <br>
# ✅ Se plantea el caso ¿Estará bien planteado?.
# <br>
# ✅ Se usó un <code>ColumnTransformer</code> para  variables categóricas y numéricas.
# <br>
# ✅ Se usó un Pipeline para encadenar el preprocesamiento de <code>ColumnTransformer</code>.
# <br>
# ✅ Según sus criterios, ¿por qué el accuracy es tan bajo?.
# <br>

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DarkBlue">
# Hemos llegado al final de nuestro colab, a seguir codeando...
# </font>
# </p>
